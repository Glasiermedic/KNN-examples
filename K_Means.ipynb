# %% [markdown]
# <a href="https://colab.research.google.com/github/Glasiermedic/KNN-examples/blob/master/K_Means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
# %matplotlib inline

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Thinkful-Ed/data-201-resources/master/cleveland.csv", header=None, error_bad_lines=False)

# Define the features and the outcome.
X = df.iloc[:, :13]
y = df.iloc[:, 13]

# Replace missing values (marked by ?) with a 0.
X = X.replace(to_replace='?', value=0)

# Binarize y so that 1 means heart disease diagnosis and 0 means no diagnosis.
y = np.where(y > 0, 0, 1)

# %%
# %%time

# Normalize the data.
X_norm = normalize(X)

# Reduce it to two components.
X_pca = PCA(2).fit_transform(X_norm)

# Calculate predicted values.
y_pred = KMeans(n_clusters=2, random_state=42).fit_predict(X_pca)

# Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1
# row_0
# 0      84  65
# 1      55  99
# CPU times: user 321 ms, sys: 163 ms, total: 484 ms
# Wall time: 283 ms

# %%
# %%time
# Each batch will be made up of 200 data points.
minibatchkmeans = MiniBatchKMeans(
    init='random',
    n_clusters=2,
    batch_size=200)
minibatchkmeans.fit(X_pca)

# Add the new predicted cluster memberships to the data frame.
predict_mini = minibatchkmeans.predict(X_pca)

# Check the MiniBatch model against our earlier one.
print('Comparing k-means and mini batch k-means solutions:')
print(pd.crosstab(predict_mini, y))
# Out:
# Comparing k-means and mini batch k-means solutions:
# col_0   0   1
# row_0
# 0      48  91
# 1      91  73
# CPU times: user 30.8 ms, sys: 2.89 ms, total: 33.7 ms
# Wall time: 36.2 ms

# %%
k_list = [2,3,4,5,6,7]
l_list = [20,30,40,50,60,70,80,90,100,200,300,400]
for k in k_list:
  for l in l_list:
    
    # Each batch will be made up of 200 data points.
    minibatchkmeans = MiniBatchKMeans(
    init='random',
    n_clusters=k,
    batch_size=(l))
    minibatchkmeans.fit(X_pca)
    
    predict_mini = minibatchkmeans.predict(X_pca)
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=predict_mini);
    plt.show()
    print('Comparing {} k-mean minibatch {} clusters against the data:'.format(k,l))
    print(pd.crosstab(predict_mini, y))
# Out:
# Comparing 2 k-mean minibatch 20 clusters against the data:
# col_0   0    1
# row_0
# 0      82   59
# 1      57  105
# Comparing 2 k-mean minibatch 30 clusters against the data:
# col_0   0    1
# row_0
# 0      61  112
# 1      78   52
# Comparing 2 k-mean minibatch 40 clusters against the data:
# col_0   0    1
# row_0
# 0      82   59
# 1      57  105
# Comparing 2 k-mean minibatch 50 clusters against the data:
# col_0   0    1
# row_0
# 0      57  105
# 1      82   59
# Comparing 2 k-mean minibatch 60 clusters against the data:
# col_0   0   1
# row_0
# 0      53  98
# 1      86  66
# Comparing 2 k-mean minibatch 70 clusters against the data:
# col_0   0    1
# row_0
# 0      73  123
# 1      66   41
# Comparing 2 k-mean minibatch 80 clusters against the data:
# col_0   0    1
# row_0
# 0      84   64
# 1      55  100
# Comparing 2 k-mean minibatch 90 clusters against the data:
# col_0   0    1
# row_0
# 0      58  109
# 1      81   55
# ...

# %% [markdown]
# In looking at the results it seems less intuitive that there could be improvement.
